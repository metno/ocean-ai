# %%
from GraphInspector import GraphInspector

path_to_graph = '/home/havardhh/Documents/2024V/met-aifs/testing/netatmo/graphs/netatmo_o96_10k_6.pt'
#path_to_graph = '/lustre/storeB/project/nwp/aifs/test_graphs/ng_awtest.pt'

path_to_output = ''

graph = GraphInspector(path_to_graph, grid_key='era', hidden_key='hidden', obs_key='netatmo')

# %%
graph.plot_grid()
# Out:
# (<Figure size 1200x600 with 1 Axes>, <GeoAxes: >)

# %%
graph.plot_obs_grid()
# Out:
# (<Figure size 1200x600 with 1 Axes>, <GeoAxes: >)

# %%
o_e_fig, o_e_ax = graph.plot_obs_encoder(xlim=(7.5,8), ylim=(59,60), save_path = "obs_enc_padding20.png")

# %%
graph.plot_obs_orphans()

# %%
o_e_fig, o_e_ax = graph.plot_obs_decoder(xlim=(7.5,8), ylim=(59,60), save_path = "obs_dec_padding20.png")

# %%
graph.plot_area_weights(xlim = (-5,20), ylim=(55,65))
# Out:
# (<Figure size 1200x600 with 2 Axes>, <GeoAxes: >)

# %%
graph.plot_obs_area_weights(xlim = (-5,20), ylim=(55,65))
# Out:
# (<Figure size 1200x600 with 2 Axes>, <GeoAxes: >)
