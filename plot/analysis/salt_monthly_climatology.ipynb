# %%
import numpy as np 
import matplotlib.pyplot as plt 
import xarray as xr

# %% [markdown]
# # Notebook dedicated to creating a nc file of salinity anomalies in May

# %%
filepath = '/lustre/storeB/project/fou/hi/foccus/datasets/norkystv3_averages'
checkpoint_mai_mean = 'norkyst800-202405_avg.nc'

# %%
ds = xr.open_dataset(f'{filepath}/{checkpoint_mai_mean}')

# %%
ds
# Out:
# <xarray.Dataset> Size: 214MB
# Dimensions:           (Y: 1148, X: 2747)
# Coordinates:
#     s_rho             float64 8B ...
#   * X                 (X) float64 22kB 0.0 800.0 1.6e+03 ... 2.196e+06 2.197e+06
#   * Y                 (Y) float64 9kB 0.0 800.0 1.6e+03 ... 9.168e+05 9.176e+05
#     s_w               float64 8B ...
#     lon               (Y, X) float64 25MB ...
#     lat               (Y, X) float64 25MB ...
# Data variables: (12/18)
#     Uwind_eastward    (Y, X) float32 13MB ...
#     Vwind_northward   (Y, X) float32 13MB ...
#     zeta              (Y, X) float32 13MB ...
#     ubar_eastward     (Y, X) float32 13MB ...
#     vbar_northward    (Y, X) float32 13MB ...
#     u_eastward        (Y, X) float32 13MB ...
#     ...                ...
#     hc                float64 8B ...
#     Cs_r              float64 8B ...
#     Cs_w              float64 8B ...
#     h                 (Y, X) float32 13MB ...
#     projection_stere  float64 8B ...
# ...

# %%
ds.salinity
# Out:
# <xarray.DataArray 'salinity' (Y: 1148, X: 2747)> Size: 13MB
# [3153556 values with dtype=float32]
# Coordinates:
#     s_rho    float64 8B ...
#   * X        (X) float64 22kB 0.0 800.0 1.6e+03 ... 2.196e+06 2.197e+06
#   * Y        (Y) float64 9kB 0.0 800.0 1.6e+03 ... 9.16e+05 9.168e+05 9.176e+05
#     s_w      float64 8B ...
#     lon      (Y, X) float64 25MB ...
#     lat      (Y, X) float64 25MB ...
# Attributes:
#     grid:                   grid
#     location:               face
#     field:                  salinity, scalar, series
#     grid_mapping:           projection_stere
#     long_name:              Sea water salinity
#     standard_name:          sea_water_salinity
#     coverage_content_type:  modelResult
#     units:                  1
#     time:                   time

# %%
norkyst_gen_path = '/lustre/storeB/project/fou/hi/foccus/datasets/symlinks/norkystv3-hindcast/2024'

norkyst_data_path4 = 'norkyst800-20240501.nc'
norkyst_data_path3 = 'norkyst800-20240502.nc'
norkyst_data_path5 = 'norkyst800-20240503.nc'
norkyst_data_path6 = 'norkyst800-20240504.nc'
norkyst_data_path7 = 'norkyst800-20240505.nc'

norkyst_data_path8 = 'norkyst800-20240506.nc'
norkyst_data_path9 = 'norkyst800-20240507.nc'
norkyst_data_path10 = 'norkyst800-20240508.nc'
norkyst_data_path11 = 'norkyst800-20240509.nc'
norkyst_data_path12 = 'norkyst800-20240510.nc'

norkyst_data_path13 = 'norkyst800-20240511.nc'
norkyst_data_path14 = 'norkyst800-20240512.nc'
norkyst_data_path15 = 'norkyst800-20240513.nc'
norkyst_data_path16 = 'norkyst800-20240514.nc'
norkyst_data_path17 = 'norkyst800-20240515.nc'

norkyst_data_path18 = 'norkyst800-20240516.nc'
norkyst_data_path19 = 'norkyst800-20240517.nc'
norkyst_data_path20 = 'norkyst800-20240518.nc'
norkyst_data_path21 = 'norkyst800-20240519.nc'
norkyst_data_path22 = 'norkyst800-20240520.nc'

norkyst_data_path23 = 'norkyst800-20240521.nc'
norkyst_data_path24 = 'norkyst800-20240522.nc'
norkyst_data_path25 = 'norkyst800-20240523.nc'
norkyst_data_path26 = 'norkyst800-20240524.nc'
norkyst_data_path27 = 'norkyst800-20240525.nc'

norkyst_data_path28 = 'norkyst800-20240526.nc'
norkyst_data_path29 = 'norkyst800-20240527.nc'
norkyst_data_path30 = 'norkyst800-20240528.nc'
norkyst_data_path31 = 'norkyst800-20240529.nc'
norkyst_data_path32 = 'norkyst800-20240530.nc'

norkyst_data_path33 = 'norkyst800-20240531.nc'

# %%
from dataloader import open_dataset

# %%
norkyst_1 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path4}', depth = -1).ds
norkyst_2 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path5}', depth = -1).ds
norkyst_3 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path6}', depth = -1).ds
norkyst_4 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path7}', depth = -1).ds
norkyst_5 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path8}', depth = -1).ds
norkyst_6 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path9}',depth = -1).ds
norkyst_7 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path10}', depth = -1).ds
norkyst_8 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path11}', depth = -1).ds
norkyst_9 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path12}', depth = -1).ds
norkyst_10 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path13}', depth = -1).ds
norkyst_11 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path14}', depth = -1).ds
norkyst_12 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path15}', depth = -1).ds
norkyst_13 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path16}', depth = -1).ds
norkyst_14 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path17}', depth = -1).ds
norkyst_15 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path18}', depth = -1).ds
norkyst_16 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path19}', depth = -1).ds
norkyst_17 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path20}', depth = -1).ds
norkyst_18 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path21}', depth = -1).ds
norkyst_19 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path22}', depth = -1).ds
norkyst_20 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path23}', depth = -1).ds
norkyst_21 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path24}', depth = -1).ds
norkyst_22 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path25}', depth = -1).ds
norkyst_23 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path26}', depth = -1).ds
norkyst_24 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path27}', depth = -1).ds
norkyst_25 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path28}', depth = -1).ds
norkyst_26 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path29}', depth = -1).ds
norkyst_27 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path30}', depth = -1).ds
norkyst_28 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path31}', depth = -1).ds
norkyst_29 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path32}', depth = -1).ds
norkyst_30 = open_dataset(f'{norkyst_gen_path}/{norkyst_data_path33}', depth = -1).ds

# %%
#to calculate the anomalies - we subtract the climatology from the salinity values of each hour
salt_clim = ds.salinity

# %%
#for easy calculations - I will gather all the files in a dictionary, however, next time I will import the netcdf4 files in an already dictionary using os

#create dict:
may = {
    'day1' : norkyst_1,
    'day2' : norkyst_2,
    'day3' : norkyst_3,
    'day4' : norkyst_4,
    'day5' : norkyst_5,
    'day6' : norkyst_6,
    'day7' : norkyst_7,
    'day8' : norkyst_8,
    'day9' : norkyst_9,
    'day10' : norkyst_10,
    'day11' : norkyst_11,
    'day12' : norkyst_12,
    'day13' : norkyst_13,
    'day14' : norkyst_14,
    'day15' : norkyst_15,
    'day16' : norkyst_16,
    'day17' : norkyst_17,
    'day18' : norkyst_18,
    'day19' : norkyst_19,
    'day20' : norkyst_20,
    'day21' : norkyst_21,
    'day22' : norkyst_22,
    'day23' : norkyst_23,
    'day24' : norkyst_24,
    'day25' : norkyst_25,
    'day26' : norkyst_26,
    'day27' : norkyst_27,
    'day28' : norkyst_28,
    'day29' : norkyst_29,
    'day30' : norkyst_30}

# %%
#select out salinity from the norkyst files
"""
anomalies = {}
for day, data in may.items():
    salinity_nor = data.salinity
    anomalies[day] = salinity_nor - salt_clim
"""

anomalies = {}
for day, data in may.items():
    salt = data.salinity 
    daily_avg = salt.resample(time = 'D').mean()
    anomalies[day] = salt - daily_avg

# %%
#how to check the data
print(anomalies.get('day1'))
# Out:
# <xarray.DataArray 'salinity' (time: 1, Y: 1148, X: 2747)> Size: 13MB
# array([[[        nan,         nan,         nan, ...,  0.00666809,
#           0.00866699,  0.00429153],
#         [        nan,         nan,         nan, ...,  0.00307846,
#           0.00178909, -0.00125122],
#         [        nan,         nan,         nan, ...,  0.00325394,
#           0.00224686,  0.00300217],
#         ...,
#         [        nan,         nan,         nan, ..., -0.02737427,
#          -0.02004242, -0.00900269],
#         [        nan,         nan,         nan, ..., -0.02204132,
#          -0.01779175, -0.01213074],
#         [        nan,         nan,         nan, ..., -0.01374435,
#          -0.01112366, -0.012043  ]]], shape=(1, 1148, 2747), dtype=float32)
# Coordinates:
#   * time     (time) datetime64[ns] 8B 2024-05-01
#   * X        (X) float64 22kB 0.0 800.0 1.6e+03 ... 2.196e+06 2.197e+06
#   * Y        (Y) float64 9kB 0.0 800.0 1.6e+03 ... 9.16e+05 9.168e+05 9.176e+05
# ...

# %%
anomalies_monthly = {}
for day, data in may.items():
    salinity_nor = data.salinity
    bla = salinity_nor - salt_clim
    anomalies_monthly[day] = bla.resample(time = 'D').mean()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[59], line 4
#       2 for day, data in may.items():
#       3     salinity_nor = data.salinity
# ----> 4     bla = salinity_nor - salt_clim
#       5     anomalies_monthly[day] = bla.resample(time = 'D').mean()
#
# File /lustre/storeB/project/fou/hi/foccus/.venv/lib64/python3.11/site-packages/xarray/core/_typed_ops.py:539, in DataArrayOpsMixin.__sub__(self, other)
#     538 def __sub__(self, other: DaCompatible) -> Self | Dataset | DataTree:
# --> 539     return self._binary_op(other, operator.sub)
#
# File /lustre/storeB/project/fou/hi/foccus/.venv/lib64/python3.11/site-packages/xarray/core/dataarray.py:4817, in DataArray._binary_op(self, other, f, reflexive)
#    4813 other_variable_or_arraylike: DaCompatible = getattr(other, "variable", other)
#    4814 other_coords = getattr(other, "coords", None)
# ...

# %%
diff = {}
for (day_d, data_d), (day_m, data_m) in zip(anomalies.items(), anomalies_monthly.items()):
    diff[day_d] = data_m - data_d

# %%
import matplotlib.pyplot as plt
one = diff['day1']
one
# Out:
# <xarray.DataArray 'salinity' (time: 1, Y: 1148, X: 2747)> Size: 13MB
# array([[[        nan,         nan,         nan, ...,  0.0700798 ,
#           0.06787491,  0.06866837],
#         [        nan,         nan,         nan, ...,  0.06959915,
#           0.06960297,  0.06966782],
#         [        nan,         nan,         nan, ...,  0.06798553,
#           0.06779099,  0.06912994],
#         ...,
#         [        nan,         nan,         nan, ..., -0.15272903,
#          -0.15747452, -0.1679573 ],
#         [        nan,         nan,         nan, ..., -0.15939331,
#          -0.16199112, -0.16924667],
#         [        nan,         nan,         nan, ..., -0.16880417,
#          -0.16928864, -0.1693306 ]]], shape=(1, 1148, 2747), dtype=float32)
# Coordinates:
#   * time     (time) datetime64[ns] 8B 2024-05-01
#   * X        (X) float64 22kB 0.0 800.0 1.6e+03 ... 2.196e+06 2.197e+06
#   * Y        (Y) float64 9kB 0.0 800.0 1.6e+03 ... 9.16e+05 9.168e+05 9.176e+05
# ...

# %%
im1 = one.plot()

# %%
im2 = anomalies['day1'].plot()

# %%
im3 = anomalies_monthly['day1'].isel(time = 0).plot()

# %%
"""
anomalies_total = list(anomalies.values())
anomaly_ds = xr.concat(anomalies_total, dim = 'time')
"""
# Out:
# "\nanomalies_total = list(anomalies.values())\nanomaly_ds = xr.concat(anomalies_total, dim = 'time')\n"

# %%
#convert into a netcdf file for easy use later
"""
output_name = '/lustre/storeB/project/fou/hi/foccus/malene/ocean-ai/plot/analysis/anomalies_may.nc'
anomaly_ds.to_netcdf(output_name)
"""
# Out:
# "\noutput_name = '/lustre/storeB/project/fou/hi/foccus/malene/ocean-ai/plot/analysis/anomalies_may.nc'\nanomaly_ds.to_netcdf(output_name)\n"
