# %%
###############################################################################################################################
# IMPORT NECESSARY PACKAGES : 
###############################################################################################################################
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import os
from typing import Tuple, Optional, Union, List

# TOOLBOX PATH :
oai_path = '/lustre/storeB/project/fou/hi/foccus/ingvild/ocean-ai'
import sys
sys.path.append(oai_path+'/plot/analysis')
from dataloader import open_dataset
from dataloader_inf import open_dataset_inf
from distribution_comparison import plot_dist_animate, plot_dist_log_animate

# %%
inference_path = '/lustre/storeB/project/fou/hi/foccus/ingvild/test_infrence/results/2024-04-02_72h_18d28_e011_s049990.nc'
inference_path = '/lustre/storeB/project/fou/hi/foccus/ingvild/test_infrence/results/2024-04-02_48h_18d28_e011_s050000.nc'
inference_path = '/lustre/storeB/project/fou/hi/foccus/ingvild/test_infrence/results/2024-04-02_48h_18d28_e002_s013968.nc'

havbris, norkyst3 = open_dataset_inf(inference_path,crop_border=True)
# Out:
# File exists and is read!
#
# Attempting to load file: /lustre/storeB/project/fou/hi/foccus/datasets/symlinks/norkystv3-hindcast/2024/norkyst800-20240402.nc
# Successfully loaded: /lustre/storeB/project/fou/hi/foccus/datasets/symlinks/norkystv3-hindcast/2024/norkyst800-20240402.nc
#
# Attempting to load file: /lustre/storeB/project/fou/hi/foccus/datasets/symlinks/norkystv3-hindcast/2024/norkyst800-20240403.nc
# Successfully loaded: /lustre/storeB/project/fou/hi/foccus/datasets/symlinks/norkystv3-hindcast/2024/norkyst800-20240403.nc
#
# Attempting to load file: /lustre/storeB/project/fou/hi/foccus/datasets/symlinks/norkystv3-hindcast/2024/norkyst800-20240404.nc
# Successfully loaded: /lustre/storeB/project/fou/hi/foccus/datasets/symlinks/norkystv3-hindcast/2024/norkyst800-20240404.nc

# %%
plot_dist_animate(norkyst3, havbris, 
                  save_name='distribution_crop', 
                  save_path='/lustre/storeB/project/fou/hi/foccus/ingvild/ocean-ai/plot/notebooks/gif_outputs/')
plot_dist_log_animate(norkyst3, havbris, 
                      save_name='distribution_log_crop', 
                      save_path='/lustre/storeB/project/fou/hi/foccus/ingvild/ocean-ai/plot/notebooks/gif_outputs/')
# Out:
# GIF created and saved: /lustre/storeB/project/fou/hi/foccus/ingvild/ocean-ai/plot/notebooks/gif_outputs/distribution_crop.gif
# GIF created and saved: /lustre/storeB/project/fou/hi/foccus/ingvild/ocean-ai/plot/notebooks/gif_outputs/distribution_log_crop.gif

# %%
plt.figure(figsize=(20,6))
plt.imshow(norkyst3.salinity.isel(time=1),vmin=33,vmax=35)
plt.colorbar()
plt.title(f'Norkyst3, timestep=1, date={havbris.isel(time=1).time.values}',fontsize=20)
plt.show()
plt.figure(figsize=(20,6))
plt.imshow(havbris.salinity.isel(time=1),vmin=33,vmax=35)
plt.colorbar()
plt.title(f'Havbris, timestep=1, date={havbris.isel(time=1).time.values}',fontsize=20)
plt.show()
diff = havbris.salinity.isel(time=1)-norkyst3.salinity.isel(time=1)
plt.figure(figsize=(20,6))
plt.imshow(diff,cmap='bwr',vmin=-0.5,vmax=0.5)
plt.colorbar()
plt.title(f'Difference (Havbris-Norkyst3), timestep=1, date={havbris.isel(time=1).time.values}',fontsize=20)
plt.show()
