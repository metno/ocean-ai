# %%
import xarray as xr
import matplotlib.pyplot as plt 
import numpy as np

# %%
import glob 
files = glob.glob('/lustre/storeB/project/fou/hi/foccus/datasets/symlinks/norkystv3-hindcast/2024/*.nc')

# %%
ds = xr.open_mfdataset(files, engine = 'netcdf4').isel(time = 0)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 ds = xr.open_mfdataset(files, engine = 'netcdf4').isel(time = 0)
#
# File /lustre/storeB/project/fou/hi/foccus/.venv/lib64/python3.11/site-packages/xarray/backends/api.py:1662, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#    1649     combined = _nested_combine(
#    1650         datasets,
#    1651         concat_dims=concat_dim,
#    (...)
#    1657         combine_attrs=combine_attrs,
#    1658     )
#    1659 elif combine == "by_coords":
#    1660     # Redo ordering from coordinates, ignoring how they were ordered
#    1661     # previously
# -> 1662     combined = combine_by_coords(
#    1663         datasets,
#    1664         compat=compat,
#    1665         data_vars=data_vars,
# ...
