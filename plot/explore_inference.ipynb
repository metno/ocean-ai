# %%
import xarray as xr
import numpy as np

# %%
filepath = '/lustre/storeB/project/fou/hi/foccus/malene/run-anemoi-ocean/ppi/external_checkpoint_inference/Inference_res/2024-04-02_.ckpt_e010_s020000.nc'
ds = xr.open_dataset(filepath)

# %%
ds.head()
# Out:
# <xarray.Dataset> Size: 12kB
# Dimensions:            (X: 5, Y: 5, time: 5)
# Coordinates:
#   * X                  (X) float64 40B 0.0 800.0 1.6e+03 2.4e+03 3.2e+03
#   * Y                  (Y) float64 40B 0.0 800.0 1.6e+03 2.4e+03 3.2e+03
#   * time               (time) datetime64[ns] 40B 2024-04-02 ... 2024-04-02T12...
# Data variables: (12/26)
#     latitude           (X, Y) float32 100B ...
#     longitude          (X, Y) float32 100B ...
#     h                  (time, X, Y) float32 500B ...
#     salinity_0         (time, X, Y) float32 500B ...
#     sea_mask           (time, X, Y) float32 500B ...
#     temperature_0      (time, X, Y) float32 500B ...
#     ...                 ...
#     rain               (time, X, Y) float32 500B ...
#     river_binary_mask  (time, X, Y) float32 500B ...
#     sin_julian_day     (time, X, Y) float32 500B ...
#     sin_latitude       (time, X, Y) float32 500B ...
#     sin_local_time     (time, X, Y) float32 500B ...
# ...

# %%
ds['temperature_0'].sel(time='2024-04-02').plot()
# Out:
# (array([ 119053.,   45103.,   46294.,  122982.,  770071., 2524473.,
#         3374686., 4590095., 2489705.,  498850.]),
#  array([-2.40646648, -1.23679817, -0.06712985,  1.10253859,  2.27220678,
#          3.44187498,  4.61154366,  5.78121185,  6.95088005,  8.12054825,
#          9.29021645]),
#  <BarContainer object of 10 artists>)
