# %%
import xarray as xr 
import numpy as np 
import glob

# %%
#check if running the code in PPI worked 
ds_fin = xr.open_dataset('/lustre/storeB/project/fou/hi/foccus/malene/ocean-ai/plot/yearly_means/seasonal_avg.nc')

# %%
ds_fin
#It worked yiha, can now try to send it through the mld calculations
# Out:
# <xarray.Dataset> Size: 17GB
# Dimensions:           (season: 4, Y: 1148, X: 2747, s_rho: 40, s_w: 41)
# Coordinates:
#   * s_rho             (s_rho) float64 320B -0.9799 -0.9403 ... -0.004904
#   * X                 (X) float64 22kB 0.0 800.0 1.6e+03 ... 2.196e+06 2.197e+06
#   * Y                 (Y) float64 9kB 0.0 800.0 1.6e+03 ... 9.168e+05 9.176e+05
#   * s_w               (s_w) float64 328B -1.0 -0.96 -0.9208 ... -0.01 0.0
#     lon               (Y, X) float64 25MB ...
#     lat               (Y, X) float64 25MB ...
#   * season            (season) <U3 48B 'DJF' 'JJA' 'MAM' 'SON'
# Data variables:
#     zeta              (season, Y, X) float64 101MB ...
#     temperature       (season, s_rho, Y, X) float64 4GB ...
#     salinity          (season, s_rho, Y, X) float64 4GB ...
#     w                 (season, s_w, Y, X) float64 4GB ...
#     ln_AKs            (season, s_w, Y, X) float64 4GB ...
#     sea_mask          (season, Y, X) float64 101MB ...
# ...

# %% [markdown]
# # Goal of notebook:
#
# **Create seasonal weights of the already mean monthly data**
#
# - Aim is to prepare dataset for calculating the mixed layer depth in the Norkyst 800.
#
# - Because of memory issues, I will rewrite the notebook into a python script and send it to PPI

# %%
filepath = '/lustre/storeB/project/fou/hi/foccus/malene/ocean-ai/plot/yearly_means'

# %%
files_winter = [f'{filepath}/December.nc', f'{filepath}/January.nc', f'{filepath}/February.nc']
files_spring = [f'{filepath}/March.nc', f'{filepath}/April.nc', f'{filepath}/May.nc']
files_summer = [f'{filepath}/June.nc', f'{filepath}/July.nc', f'{filepath}/August.nc']
files_fall = [f'{filepath}/September.nc', f'{filepath}/October.nc', f'{filepath}/November.nc']

# %%
winter = xr.open_mfdataset(files_winter).sortby('time')
spring = xr.open_mfdataset(files_spring).sortby('time')
summer = xr.open_mfdataset(files_summer).sortby('time')
fall = xr.open_mfdataset(files_fall).sortby('time')

# %%
year = xr.open_mfdataset(f'{filepath}/*.nc')

# %%
fall
#summer
#spring
#winter
# Out:
# <xarray.Dataset> Size: 6GB
# Dimensions:           (time: 3, Y: 1148, X: 2747, s_rho: 40, s_w: 41)
# Coordinates:
#   * s_rho             (s_rho) float64 320B -0.9799 -0.9403 ... -0.004904
#   * s_w               (s_w) float64 328B -1.0 -0.96 -0.9208 ... -0.01 0.0
#   * X                 (X) float64 22kB 0.0 800.0 1.6e+03 ... 2.196e+06 2.197e+06
#   * Y                 (Y) float64 9kB 0.0 800.0 1.6e+03 ... 9.168e+05 9.176e+05
#     lon               (Y, X) float64 25MB dask.array<chunksize=(1148, 2747), meta=np.ndarray>
#     lat               (Y, X) float64 25MB dask.array<chunksize=(1148, 2747), meta=np.ndarray>
#   * time              (time) datetime64[ns] 24B 2024-09-30 2024-10-31 2024-11-30
# Data variables:
#     zeta              (time, Y, X) float32 38MB dask.array<chunksize=(1, 1148, 2747), meta=np.ndarray>
#     temperature       (time, s_rho, Y, X) float32 2GB dask.array<chunksize=(1, 40, 1148, 2747), meta=np.ndarray>
# ...

# %%
year
# Out:
# <xarray.Dataset> Size: 25GB
# Dimensions:           (time: 12, Y: 1148, X: 2747, s_rho: 40, s_w: 41)
# Coordinates:
#   * s_rho             (s_rho) float64 320B -0.9799 -0.9403 ... -0.004904
#   * X                 (X) float64 22kB 0.0 800.0 1.6e+03 ... 2.196e+06 2.197e+06
#   * Y                 (Y) float64 9kB 0.0 800.0 1.6e+03 ... 9.168e+05 9.176e+05
#   * s_w               (s_w) float64 328B -1.0 -0.96 -0.9208 ... -0.01 0.0
#     lon               (Y, X) float64 25MB dask.array<chunksize=(1148, 2747), meta=np.ndarray>
#     lat               (Y, X) float64 25MB dask.array<chunksize=(1148, 2747), meta=np.ndarray>
#   * time              (time) datetime64[ns] 96B 2024-01-31 ... 2024-12-31
# Data variables:
#     zeta              (time, Y, X) float32 151MB dask.array<chunksize=(1, 1148, 2747), meta=np.ndarray>
#     temperature       (time, s_rho, Y, X) float32 6GB dask.array<chunksize=(1, 40, 1148, 2747), meta=np.ndarray>
# ...

# %%
#Will try to make seasonal weights based on the xarray - but have to manually do so as the xarray has daily values, I have monthly, so can not use all built in funcs
month_lengths = [31, 29, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
m = month_lengths
DJF = m[-1] + m[0] + m[1]
MAM = m[2] + m[3] + m[4]
JJA = m[5] + m[6] + m[7]
SON = m[8] + m[9] + m[10]

# %%
weights = []
for i in month_lengths[0:2]:
    weights.append(i / DJF)
for j in month_lengths[2:5]:
    weights.append(j/MAM)
for k in month_lengths[5:8]:
    weights.append(k/JJA)
for v in month_lengths[8:11]:
    weights.append(v/SON)
weights.append(month_lengths[-1] / DJF)

weights
# Out:
# [0.34065934065934067,
#  0.31868131868131866,
#  0.33695652173913043,
#  0.32608695652173914,
#  0.33695652173913043,
#  0.32608695652173914,
#  0.33695652173913043,
#  0.33695652173913043,
#  0.32967032967032966,
#  0.34065934065934067,
#  0.32967032967032966,
#  0.34065934065934067]

# %%
#ensure that the weights are correctly calculated, sum should be 1
print(weights[0] + weights[1] + weights[-1])
print(weights[2] + weights[3] + weights[4])
print(weights[5] + weights[6] + weights[7])
print(weights[8] + weights[9] + weights[10])
#yepss
# Out:
# 1.0
# 1.0
# 1.0
# 1.0

# %%
year
# Out:
# <xarray.Dataset> Size: 25GB
# Dimensions:           (time: 12, Y: 1148, X: 2747, s_rho: 40, s_w: 41)
# Coordinates:
#   * s_rho             (s_rho) float64 320B -0.9799 -0.9403 ... -0.004904
#   * X                 (X) float64 22kB 0.0 800.0 1.6e+03 ... 2.196e+06 2.197e+06
#   * Y                 (Y) float64 9kB 0.0 800.0 1.6e+03 ... 9.168e+05 9.176e+05
#   * s_w               (s_w) float64 328B -1.0 -0.96 -0.9208 ... -0.01 0.0
#     lon               (Y, X) float64 25MB dask.array<chunksize=(1148, 2747), meta=np.ndarray>
#     lat               (Y, X) float64 25MB dask.array<chunksize=(1148, 2747), meta=np.ndarray>
#   * time              (time) datetime64[ns] 96B 2024-01-31 ... 2024-12-31
# Data variables:
#     zeta              (time, Y, X) float32 151MB dask.array<chunksize=(1, 1148, 2747), meta=np.ndarray>
#     temperature       (time, s_rho, Y, X) float32 6GB dask.array<chunksize=(1, 40, 1148, 2747), meta=np.ndarray>
# ...

# %%
print(len(weights))
print(year.dims)
# Out:
# 12
# FrozenMappingWarningOnValuesAccess({'time': 12, 'Y': 1148, 'X': 2747, 's_rho': 40, 's_w': 41})

# %%
Weights = xr.DataArray(
    weights,
    dims = ['time'],
    coords = {'time' : year.time})

# %%
ds = (year * Weights).groupby('time.season').sum(dim='time')

# %%
ds
# Out:
# <xarray.Dataset> Size: 17GB
# Dimensions:           (season: 4, Y: 1148, X: 2747, s_rho: 40, s_w: 41)
# Coordinates:
#   * s_rho             (s_rho) float64 320B -0.9799 -0.9403 ... -0.004904
#   * X                 (X) float64 22kB 0.0 800.0 1.6e+03 ... 2.196e+06 2.197e+06
#   * Y                 (Y) float64 9kB 0.0 800.0 1.6e+03 ... 9.168e+05 9.176e+05
#   * s_w               (s_w) float64 328B -1.0 -0.96 -0.9208 ... -0.01 0.0
#     lon               (Y, X) float64 25MB dask.array<chunksize=(1148, 2747), meta=np.ndarray>
#     lat               (Y, X) float64 25MB dask.array<chunksize=(1148, 2747), meta=np.ndarray>
#   * season            (season) object 32B 'DJF' 'JJA' 'MAM' 'SON'
# Data variables:
#     zeta              (season, Y, X) float64 101MB dask.array<chunksize=(1, 1148, 2747), meta=np.ndarray>
#     temperature       (season, s_rho, Y, X) float64 4GB dask.array<chunksize=(1, 40, 1148, 2747), meta=np.ndarray>
# ...
