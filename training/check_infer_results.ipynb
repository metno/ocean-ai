# %% [markdown]
# # Look at infer results

# %%
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
dir = '/lustre/storeB/project/fou/hi/foccus/ina/OceanAI/training/outputs/experiment1/'
file = dir + '7e296243.nc'
ds = xr.open_dataset(file)

print(ds.longitude)
# Out:
# <xarray.DataArray 'longitude' (values: 1822664)> Size: 7MB
# [1822664 values with dtype=float32]
# Dimensions without coordinates: values
# Attributes:
#     units:      degrees_east
#     long_name:  longitude

# %%
fig = plt.figure(figsize=(20,20))
ax = plt.axes()

c = ax.scatter(ds.longitude,ds.latitude,c=ds.isel(time=1)['temperature_1'],s=5)

#plt.show()

# %%
fig = plt.figure(figsize=(20,20))
ax = plt.axes()

c = ax.scatter(ds.longitude,ds.latitude,c=ds.isel(time=1)['temperature_100'],s=5)

# %%
fig = plt.figure(figsize=(20,20))
ax = plt.axes()

c = ax.scatter(ds.longitude,ds.latitude,c=ds.isel(time=1)['temperature_300'],s=5)
