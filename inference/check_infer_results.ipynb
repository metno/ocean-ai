# %% [markdown]
# # Look at infer results

# %%
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
#ex_code = 62677636
dir = '/lustre/storeB/project/fou/hi/foccus/experiments/temp-jan/'
file = dir + '62677636-infer-lt2.nc'
ds = xr.open_dataset(file)

print(ds.longitude)
# Out:
# <xarray.DataArray 'longitude' (values: 1822664)> Size: 7MB
# [1822664 values with dtype=float32]
# Dimensions without coordinates: values
# Attributes:
#     units:      degrees_east
#     long_name:  longitude

# %%
fig = plt.figure(figsize=(20,20))
ax = plt.axes()

c = ax.scatter(ds.longitude,ds.latitude,c=ds.isel(time=1)['temperature_1'],s=5)

#plt.show()

# %%
fig = plt.figure(figsize=(20,20))
ax = plt.axes()

c = ax.scatter(ds.longitude,ds.latitude,c=ds.isel(time=1)['temperature_1'],s=5)

# %%
fig = plt.figure(figsize=(20,20))
ax = plt.axes()

c = ax.scatter(ds.longitude,ds.latitude,c=ds.isel(time=1)['temperature_300'],s=5)

# %%
#ex_code = 62677636
file2 = dir + '62677636-infer.nc'
ds2 = xr.open_dataset(file2)

# %%
# Print the data variables and their dimensions
for var in ds.data_vars:
    print(f"Variable: {var}")
    print(f"Dimensions: {ds[var].dims}")
    print(f"Shape: {ds[var].shape}")
    print()
# Out:
# Variable: latitude
# Dimensions: ('values',)
# Shape: (1822664,)
#
# Variable: longitude
# Dimensions: ('values',)
# Shape: (1822664,)
#
# Variable: temperature_0
# Dimensions: ('time', 'values')
# Shape: (2, 1822664)
#
# Variable: temperature_1
# Dimensions: ('time', 'values')
# Shape: (2, 1822664)
#
# Variable: temperature_10
# Dimensions: ('time', 'values')
# Shape: (2, 1822664)
#
# Variable: temperature_100
# Dimensions: ('time', 'values')
# Shape: (2, 1822664)
#
# Variable: temperature_15
# Dimensions: ('time', 'values')
# Shape: (2, 1822664)
#
# Variable: temperature_2
# Dimensions: ('time', 'values')
# Shape: (2, 1822664)
#
# Variable: temperature_200
# Dimensions: ('time', 'values')
# Shape: (2, 1822664)
#
# Variable: temperature_25
# Dimensions: ('time', 'values')
# Shape: (2, 1822664)
#
# Variable: temperature_3
# Dimensions: ('time', 'values')
# Shape: (2, 1822664)
#
# Variable: temperature_300
# Dimensions: ('time', 'values')
# Shape: (2, 1822664)
#
# ...

# %%
fig2 = plt.figure(figsize=(20,20))
ax2 = plt.axes()

c2 = ax2.scatter(ds2.longitude,ds2.latitude,c=ds2.isel(time=1)['temperature_1'],s=3)
